# %%
from tensorflow.keras.models import load_model

model_loaded = load_model(r'C:\Users\Mahesh\Desktop\ml(anpd)\my_model.h5')

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Provide the path to your test image
path = data_folder = "C:\\Users\\Mahesh\\Desktop\\ml(anpd)\\test5.jpg"

def object_detection(path):
    # Read image
    image = load_img(path)  # PIL Object
    image = np.array(image, dtype=np.uint8)  # 8 bit array - Range(0,255)
    image1 = load_img(path, target_size=(224, 224))

    # Preprocessing
    image_arr_224 = img_to_array(image1) / 255.0  # Convert to array and normalize

    h, w, d = image.shape
    test_array = image_arr_224.reshape(1, 224, 224, 3)

    # Make Predictions
    coords = model_loaded.predict(test_array)
    denorm = np.array([w, w, h, h])

    # Denormalize the output
    coords = coords * denorm
    coords = coords.astype(np.int32)

    # Drawing a Bounding Box on top of this image
    xmin, xmax, ymin, ymax = coords[0]
    pt1 = (xmin, ymin)
    pt2 = (xmax, ymax)

    cv2.rectangle(image, pt1, pt2, (0, 255, 0), 3)

    return image, coords

# Perform object detection on your test image
result_image, predicted_coords = object_detection(path)

# Display the result
plt.figure(figsize=(10, 8))
plt.imshow(result_image)
plt.show()

# You can also access the predicted coordinates if needed
print("Predicted Coordinates:", predicted_coords)
# Out:
# 1/1 [==============================] - 4s 4s/step
# Predicted Coordinates: [[ 155  461  840 1051]]

# %%
predicted_coords[0]
# Out:
# array([ 155,  461,  840, 1051])

# %%
img = np.array(load_img(path))
xmin, xmax, ymin, ymax = predicted_coords[0]
roi = img[ymin:ymax,xmin:xmax]
plt.imshow(roi)
plt.show()

# %%
# !pip install pytesseract
# Out:
# ...
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\mahesh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\mahesh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\mahesh\anaconda3\lib\site-packages)
# WARNING: Error parsing requirements for protobuf: [Errno 2] No such file or directory: 'c:\\users\\mahesh\\anaconda3\\lib\\site-packages\\protobuf-3.20.3.dist-info\\METADATA'
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\mahesh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\mahesh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\mahesh\anaconda3\lib\site-packages)

# %%
# !pip list
# Out:
# Package                       Version         Editable project location
# ----------------------------- --------------- ------------------------------------------------------------
# absl-py                       1.4.0
# aiohttp                       3.8.1
# aiosignal                     1.3.1
# alabaster                     0.7.12
# anaconda-client               1.11.1
# anaconda-navigator            2.4.0
# anaconda-project              0.11.1
# anyio                         3.5.0
# apache-beam                   2.53.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# astroid                       2.14.2
# astropy                       5.1
# asttokens                     2.0.5
# astunparse                    1.6.3
# async-timeout                 4.0.3
# atomicwrites                  1.4.0
# attrs                         22.1.0
# Automat                       20.2.0
# ...

# %%
import pytesseract as pt

# %%
pt.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
#extract text from image
text = pt.image_to_string(roi)
print(text)

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import cv2
import numpy as np

# Provide the path to your test image
path = data_folder = "C:/Users/Mahesh/Desktop/m/dataset/BR7.jpg"

def object_detection(path):
    # Read image
    image = load_img(path)  # PIL Object
    image = np.array(image, dtype=np.uint8)  # 8 bit array - Range(0,255)
    image1 = load_img(path, target_size=(224, 224))

    # Preprocessing
    image_arr_224 = img_to_array(image1) / 255.0  # Convert to array and normalize

    h, w, d = image.shape
    test_array = image_arr_224.reshape(1, 224, 224, 3)

    # Make Predictions
    coords = model_loaded.predict(test_array)
    denorm = np.array([w, w, h, h])

    # Denormalize the output
    coords = coords * denorm
    coords = coords.astype(np.int32)

    # Drawing a Bounding Box on top of this image
    xmin, xmax, ymin, ymax = coords[0]
    pt1 = (xmin, ymin)
    pt2 = (xmax, ymax)

    cv2.rectangle(image, pt1, pt2, (0, 255, 0), 3)

    return image, coords

# Perform object detection on your test image
result_image, predicted_coords = object_detection(path)

# Display the result
plt.figure(figsize=(10, 8))
plt.imshow(result_image)
plt.show()

# You can also access the predicted coordinates if needed
print("Predicted Coordinates:", predicted_coords)

img = np.array(load_img(path))
xmin, xmax, ymin, ymax = predicted_coords[0]
roi = img[ymin:ymax,xmin:xmax]
plt.imshow(roi)
plt.show()
# Out:
# 1/1 [==============================] - 0s 168ms/step
# Predicted Coordinates: [[ 81 189 303 328]]

# %%
#extract text from image
text = pt.image_to_string(roi)
print(text)
# Out:
# BR-14 E-1206

# %%
# Provide the path to your test image
path = data_folder = r'C:\Users\Mahesh\Desktop\ml(anpd)\test2.jpg'

def object_detection(path):
    # Read image
    image = load_img(path)  # PIL Object
    image = np.array(image, dtype=np.uint8)  # 8 bit array - Range(0,255)
    image1 = load_img(path, target_size=(224, 224))

    # Preprocessing
    image_arr_224 = img_to_array(image1) / 255.0  # Convert to array and normalize

    h, w, d = image.shape
    test_array = image_arr_224.reshape(1, 224, 224, 3)

    # Make Predictions
    coords = model_loaded.predict(test_array)
    denorm = np.array([w, w, h, h])

    # Denormalize the output
    coords = coords * denorm
    coords = coords.astype(np.int32)

    # Drawing a Bounding Box on top of this image
    xmin, xmax, ymin, ymax = coords[0]
    pt1 = (xmin, ymin)
    pt2 = (xmax, ymax)

    cv2.rectangle(image, pt1, pt2, (0, 255, 0), 3)

    return image, coords

# Perform object detection on your test image
result_image, predicted_coords = object_detection(path)

# Display the result
plt.figure(figsize=(10, 8))
plt.imshow(result_image)
plt.show()

# You can also access the predicted coordinates if needed
print("Predicted Coordinates:", predicted_coords)

img = np.array(load_img(path))
xmin, xmax, ymin, ymax = predicted_coords[0]
roi = img[ymin:ymax,xmin:xmax]
plt.imshow(roi)
plt.show()
# Out:
# 1/1 [==============================] - 0s 202ms/step
# Predicted Coordinates: [[ 828 1284  765 1000]]

# %%
#extract text from image
text = pt.image_to_string(roi)
print(text)
# Out:
# “Su” |
# KAZ6 2529

# %%
# Provide the path to your test image
path = data_folder = r'C:\Users\Mahesh\Desktop\ml(anpd)\test6.jpg'

def object_detection(path):
    # Read image
    image = load_img(path)  # PIL Object
    image = np.array(image, dtype=np.uint8)  # 8 bit array - Range(0,255)
    image1 = load_img(path, target_size=(224, 224))

    # Preprocessing
    image_arr_224 = img_to_array(image1) / 255.0  # Convert to array and normalize

    h, w, d = image.shape
    test_array = image_arr_224.reshape(1, 224, 224, 3)

    # Make Predictions
    coords = model_loaded.predict(test_array)
    denorm = np.array([w, w, h, h])

    # Denormalize the output
    coords = coords * denorm
    coords = coords.astype(np.int32)

    # Drawing a Bounding Box on top of this image
    xmin, xmax, ymin, ymax = coords[0]
    pt1 = (xmin, ymin)
    pt2 = (xmax, ymax)

    cv2.rectangle(image, pt1, pt2, (0, 255, 0), 3)

    return image, coords

# Perform object detection on your test image
result_image, predicted_coords = object_detection(path)

# Display the result
plt.figure(figsize=(10, 8))
plt.imshow(result_image)
plt.show()

# You can also access the predicted coordinates if needed
print("Predicted Coordinates:", predicted_coords)

img = np.array(load_img(path))
xmin, xmax, ymin, ymax = predicted_coords[0]
roi = img[ymin:ymax,xmin:xmax]
plt.imshow(roi)
plt.show()
# Out:
# 1/1 [==============================] - 0s 184ms/step
# Predicted Coordinates: [[0 0 0 0]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 47
#      45 xmin, xmax, ymin, ymax = predicted_coords[0]
#      46 roi = img[ymin:ymax,xmin:xmax]
# ---> 47 plt.imshow(roi)
#      48 plt.show()
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2668, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2662 @_copy_docstring_and_deprecators(Axes.imshow)
#    2663 def imshow(
#    2664         X, cmap=None, norm=None, *, aspect=None, interpolation=None,
#    2665         alpha=None, vmin=None, vmax=None, origin=None, extent=None,
#    2666         interpolation_stage=None, filternorm=True, filterrad=4.0,
# ...

# %%
#extract text from image
text = pt.image_to_string(roi)
print(text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 2
#       1 #extract text from image
# ----> 2 text = pt.image_to_string(roi)
#       3 print(text)
#
# File ~\anaconda3\lib\site-packages\pytesseract\pytesseract.py:423, in image_to_string(image, lang, config, nice, output_type, timeout)
#     418 """
#     419 Returns the result of a Tesseract OCR run on the provided image to string
#     420 """
#     421 args = [image, 'txt', lang, config, nice, timeout]
# --> 423 return {
#     424     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     425     Output.DICT: lambda: {'text': run_and_get_output(*args)},
#     426     Output.STRING: lambda: run_and_get_output(*args),
#     427 }[output_type]()
#
# File ~\anaconda3\lib\site-packages\pytesseract\pytesseract.py:426, in image_to_string.<locals>.<lambda>()
#     418 """
# ...
